# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

from files.sb_utils import save_file

# %%
#load in anime and manga data

# %%
anime_data = pd.read_csv(r'C:\Users\sydne\Desktop\Springboard\Cap2\Anime_Manga_Capstone\anime\anime.csv')

# %%
manga_data = pd.read_csv(r'C:\Users\sydne\Desktop\Springboard\Cap2\Anime_Manga_Capstone\manga\manga.csv')

# %%
#check out anime and manga data using head, describe,index and columns

# %%
anime_data.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1671587
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3      9253                         Steins;Gate     tv   9.07    1348232
# 4     28851                      Koe no Katachi  movie   8.94    1540277
#
#             status  episodes  start_date    end_date        source  ...  \
# 0  finished_airing      64.0  2009-04-05  2010-07-04         manga  ...
# 1  finished_airing     148.0  2011-10-02  2014-09-24         manga  ...
# 2  finished_airing      10.0  2019-04-29  2019-07-01         manga  ...
# 3  finished_airing      24.0  2011-04-06  2011-09-14  visual_novel  ...
# 4  finished_airing       1.0  2016-09-17  2016-09-17         manga  ...
#
#                                            producers  \
# ...

# %%
anime_data.describe()
# Out:
#            anime_id         score     scored_by      episodes       members  \
# count  24985.000000  16050.000000  2.498500e+04  24438.000000  2.498500e+04
# mean   29871.034100      6.418470  1.915352e+04     14.877486  3.758410e+04
# std    18020.608498      0.899305  9.486704e+04     48.447625  1.583635e+05
# min        1.000000      1.850000  0.000000e+00      1.000000  0.000000e+00
# 25%    10545.000000      5.800000  5.100000e+01      1.000000  2.200000e+02
# 50%    34692.000000      6.420000  3.070000e+02      2.000000  1.085000e+03
# 75%    45347.000000      7.070000  3.433000e+03     13.000000  9.499000e+03
# max    56202.000000      9.100000  2.685033e+06   3057.000000  3.779820e+06
#
#            favorites    start_year
# count   24985.000000  20301.000000
# mean      437.147328   2008.798237
# std      4390.169453     13.404009
# min         0.000000   1917.000000
# 25%         0.000000   2003.000000
# 50%         1.000000   2013.000000
# ...

# %%
anime_data.index
# Out:
# RangeIndex(start=0, stop=24985, step=1)

# %%
anime_data.columns
# Out:
# Index(['anime_id', 'title', 'type', 'score', 'scored_by', 'status', 'episodes',
#        'start_date', 'end_date', 'source', 'members', 'favorites',
#        'episode_duration', 'total_duration', 'rating', 'sfw', 'approved',
#        'created_at', 'updated_at', 'start_year', 'start_season',
#        'real_start_date', 'real_end_date', 'broadcast_day', 'broadcast_time',
#        'genres', 'themes', 'demographics', 'studios', 'producers', 'licensors',
#        'synopsis', 'background', 'main_picture', 'url', 'trailer_url',
#        'title_english', 'title_japanese', 'title_synonyms'],
#       dtype='object')

# %%
manga_data.head()
# Out:
#    manga_id                                            title   type  score  \
# 0         2                                          Berserk  manga   9.47
# 1        13                                        One Piece  manga   9.22
# 2      1706  JoJo no Kimyou na Bouken Part 7: Steel Ball Run  manga   9.30
# 3      4632                                   Oyasumi Punpun  manga   9.02
# 4        25                              Fullmetal Alchemist  manga   9.03
#
#    scored_by                status  volumes  chapters  start_date    end_date  \
# 0     319696  currently_publishing      NaN       NaN  1989-08-25         NaN
# 1     355375  currently_publishing      NaN       NaN  1997-07-22         NaN
# 2     151433              finished     24.0      96.0  2004-01-19  2011-04-19
# 3     168459              finished     13.0     147.0  2007-03-15  2013-11-02
# 4     153151              finished     27.0     116.0  2001-07-12  2010-09-11
#
#    ...           demographics  \
# ...

# %%
manga_data.describe()
# Out:
#             manga_id         score      scored_by       volumes      chapters  \
# count   64833.000000  24636.000000   64833.000000  48211.000000  46042.000000
# mean    77098.238042      6.945179     686.997501      2.970090     21.186417
# std     48549.548139      0.520170    5514.493705      4.771116     53.896370
# min         1.000000      2.440000       0.000000      1.000000      1.000000
# 25%     26466.000000      6.620000       7.000000      1.000000      5.000000
# 50%     85847.000000      6.910000      46.000000      1.000000      9.000000
# 75%    115701.000000      7.250000     261.000000      3.000000     19.000000
# max    161613.000000      9.470000  394362.000000    200.000000   6477.000000
#
#              members      favorites
# count   64833.000000   64833.000000
# mean     1758.756127      54.991440
# std     11083.107361    1057.059487
# min         3.000000       0.000000
# 25%        64.000000       0.000000
# 50%       190.000000       0.000000
# ...

# %%
manga_data.index
# Out:
# RangeIndex(start=0, stop=64833, step=1)

# %%
manga_data.columns
# Out:
# Index(['manga_id', 'title', 'type', 'score', 'scored_by', 'status', 'volumes',
#        'chapters', 'start_date', 'end_date', 'members', 'favorites', 'sfw',
#        'approved', 'created_at_before', 'updated_at', 'real_start_date',
#        'real_end_date', 'genres', 'themes', 'demographics', 'authors',
#        'serializations', 'synopsis', 'background', 'main_picture', 'url',
#        'title_english', 'title_japanese', 'title_synonyms'],
#       dtype='object')

# %%
#check out the types of both datasets

# %%
anime_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24985 entries, 0 to 24984
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anime_id          24985 non-null  int64
#  1   title             24985 non-null  object
#  2   type              24927 non-null  object
#  3   score             16050 non-null  float64
#  4   scored_by         24985 non-null  int64
#  5   status            24985 non-null  object
#  6   episodes          24438 non-null  float64
#  7   start_date        24110 non-null  object
#  8   end_date          22215 non-null  object
#  9   source            21424 non-null  object
#  10  members           24985 non-null  int64
#  11  favorites         24985 non-null  int64
#  12  episode_duration  24387 non-null  object
#  13  total_duration    24162 non-null  object
#  14  rating            24405 non-null  object
#  15  sfw               24985 non-null  bool
# ...

# %%
manga_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64833 entries, 0 to 64832
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   manga_id           64833 non-null  int64
#  1   title              64833 non-null  object
#  2   type               64833 non-null  object
#  3   score              24636 non-null  float64
#  4   scored_by          64833 non-null  int64
#  5   status             64833 non-null  object
#  6   volumes            48211 non-null  float64
#  7   chapters           46042 non-null  float64
#  8   start_date         62950 non-null  object
#  9   end_date           51932 non-null  object
#  10  members            64833 non-null  int64
#  11  favorites          64833 non-null  int64
#  12  sfw                64833 non-null  bool
#  13  approved           64833 non-null  bool
#  14  created_at_before  64833 non-null  object
#  15  updated_at         62678 non-null  object
# ...

# %%
# check both data sets for unique titles

# %%
anime_data['title'].value_counts()
# Out:
# title
# Urahara                             2
# Fullmetal Alchemist: Brotherhood    1
# Boku to Roboko Movie                1
# Yawarakame♥                         1
# Moshimoshi, Terumi desu.            1
#                                    ..
# Momoiro Milk                        1
# Super Dragon Ball Heroes            1
# Kirameki Inokori Daisensou          1
# Mizugumo Monmon                     1
# Ame to Kusari                       1
# Name: count, Length: 24984, dtype: int64

# %%
anime_data[anime_data['title'] == 'Urahara']
#it appears that one Urahara can be dropped from the df
# Out:
#        anime_id    title type  score  scored_by           status  episodes  \
# 8166      35250  Urahara   tv   5.76       8819  finished_airing      12.0
# 18775     56182  Urahara  NaN    NaN          0    not_yet_aired       NaN
#
#        start_date    end_date     source  ...  \
# 8166   2017-10-04  2017-12-20  web_manga  ...
# 18775         NaN         NaN   original  ...
#
#                                                producers       licensors  \
# 8166   ['VAP', 'Sotsu', 'bilibili', 'Crunchyroll SC A...  ['Funimation']
# 18775                                    ['Pony Canyon']              []
#
#                                                 synopsis background  \
# 8166   Three high school girls are putting together a...        NaN
# 18775                                                NaN        NaN
#
#                                             main_picture  \
# 8166   https://cdn.myanimelist.net/images/anime/12/88...
# ...

# %%
 manga_data['title'].value_counts()
# Out:
# title
# Hatsukoi                                                                     9
# Switch                                                                       7
# Himitsu no Hanazono                                                          6
# Red                                                                          6
# Kanon                                                                        5
#                                                                             ..
# Ibara no Koi                                                                 1
# Sawaranaide, Kowareteimasu.                                                  1
# Marshmallow Honey                                                            1
# Uchi no Ojousama no Hanashi wo Kiite Kure: Akuyaku Reijou Kouryaku Kiroku    1
# Kidou Senshi Gundam F91 Prequel                                              1
# Name: count, Length: 62414, dtype: int64

# %%
#lets look at the most duplicated value in manga
manga_data[manga_data['title'] == 'Hatsukoi']
# Out:
#        manga_id     title         type  score  scored_by    status  volumes  \
# 1663     100249  Hatsukoi        manga   7.70       2325  finished      1.0
# 6069      57805  Hatsukoi        manga   7.10       1017  finished      1.0
# 23343     44697  Hatsukoi     one_shot   6.08        195  finished      NaN
# 36443     21973  Hatsukoi        manga    NaN         15  finished      1.0
# 37608     78465  Hatsukoi     one_shot    NaN         74  finished      NaN
# 44355    137852  Hatsukoi     one_shot    NaN         31  finished      NaN
# 48248    139170  Hatsukoi    doujinshi    NaN         23  finished      1.0
# 50556     86002  Hatsukoi        manga    NaN          4  finished      1.0
# 57414    106555  Hatsukoi  light_novel    NaN          1  finished      1.0
#
#        chapters  start_date    end_date  ...  demographics  \
# 1663        8.0  2016-07-22  2017-07-22  ...            []
# 6069        6.0  2013-05-30  2013-05-30  ...            []
# ...

# %%
#It appears that the most dupliacted value Hatsukoi, were all different based on id, start date, end date
#due to manga titles having a lot of duplicate titles, let's check if their ids also duplicate

# %%
manga_data['manga_id'].value_counts()
# Out:
# manga_id
# 2         1
# 101486    1
# 92055     1
# 92233     1
# 93478     1
#          ..
# 13496     1
# 130430    1
# 29845     1
# 88342     1
# 158167    1
# Name: count, Length: 64833, dtype: int64

# %%
#all ids only appear once, for now we can assume that even though there were many manga with duplicate titles, they are all different

# %%
#check if there are any missing values in the datasets

# %%
missing = pd.concat([anime_data.isnull().sum(), 100 * anime_data.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by=['count'], ascending = True)
# Out:
#                   count          %
# anime_id              0   0.000000
# url                   0   0.000000
# licensors             0   0.000000
# producers             0   0.000000
# studios               0   0.000000
# demographics          0   0.000000
# themes                0   0.000000
# genres                0   0.000000
# updated_at            0   0.000000
# created_at            0   0.000000
# approved              0   0.000000
# sfw                   0   0.000000
# title_synonyms        0   0.000000
# favorites             0   0.000000
# members               0   0.000000
# title                 0   0.000000
# scored_by             0   0.000000
# status                0   0.000000
# type                 58   0.232139
# title_japanese       90   0.360216
# main_picture        154   0.616370
# episodes            547   2.189314
# rating              580   2.321393
# episode_duration    598   2.393436
# total_duration      823   3.293976
# start_date          875   3.502101
# ...

# %%
missingManga = pd.concat([manga_data.isnull().sum(), 100 * manga_data.isnull().mean()], axis=1)
missingManga.columns=['count', '%']
missingManga.sort_values(by=['count'], ascending = True)
# Out:
#                    count          %
# manga_id               0   0.000000
# url                    0   0.000000
# serializations         0   0.000000
# authors                0   0.000000
# demographics           0   0.000000
# themes                 0   0.000000
# genres                 0   0.000000
# approved               0   0.000000
# sfw                    0   0.000000
# favorites              0   0.000000
# created_at_before      0   0.000000
# scored_by              0   0.000000
# title                  0   0.000000
# type                   0   0.000000
# members                0   0.000000
# status                 0   0.000000
# title_synonyms         0   0.000000
# main_picture          56   0.086376
# title_japanese      1133   1.747567
# start_date          1883   2.904385
# real_start_date     1883   2.904385
# updated_at          2155   3.323925
# real_end_date      12901  19.898817
# end_date           12901  19.898817
# volumes            16622  25.638178
# ...

# %%
#let's consider what columns are important for our employers desires: Finding out what makes an anime or manga popular
#Ratings are important to see which anime/manga are popular. so is genre, demographics, authors/studio, themes, a manga's serialisation company
#and if a manga is multi-volume or an anime's episode length( or ongoing) also play a factor.  
#For now, let's get rid of any uncessary columns for both datasets.

# %%
#drop columns starting with the anime dataset

# %%
anime_data = anime_data.drop(columns =['url', 'licensors', 'producers','updated_at','created_at', 'approved','sfw','favorites', 'members','main_picture','episode_duration', 'total_duration', 'start_date', 'real_start_date', 'end_date', 'real_end_date', 'synopsis', 'start_season', 'trailer_url', 'broadcast_day', 'broadcast_time','background', 'title_english', 'title_synonyms', 'title_japanese'])

# %%
# drop rows that do not have score
anime_data = anime_data[anime_data['score'].notna()]
anime_data
# Out:
#        anime_id                                         title   type  score  \
# 0          5114              Fullmetal Alchemist: Brotherhood     tv   9.10
# 1         11061                        Hunter x Hunter (2011)     tv   9.04
# 2         38524            Shingeki no Kyojin Season 3 Part 2     tv   9.05
# 3          9253                                   Steins;Gate     tv   9.07
# 4         28851                                Koe no Katachi  movie   8.94
# ...         ...                                           ...    ...    ...
# 16045     24811                                   Prison Bear    ona   4.84
# 16046     30408                                     Tokyo SOS  movie   4.90
# 16047     33861  Nani no Yaku ni Mo Tatanai Karappona Hanashi    ona   5.08
# 16048     18353                          Hadakya no Otonosama    ona   4.83
# 16049     32862                                  Never Shined  music   4.92
#
# ...

# %%
#now let's drop unimportant columns in manga dataset
manga_data= manga_data.drop(columns = ['url','approved', 'sfw', 'favorites', 'created_at_before', 'members', 'main_picture', 'start_date', 'real_start_date', 'updated_at', 'real_end_date', 'end_date', 'synopsis', 'background', 'title_japanese', 'title_synonyms', 'title_english'])

# %%
manga_data = manga_data[manga_data['score'].notna()]
manga_data
# Out:
#        manga_id                                              title       type  \
# 0             2                                            Berserk      manga
# 1            13                                          One Piece      manga
# 2          1706    JoJo no Kimyou na Bouken Part 7: Steel Ball Run      manga
# 3          4632                                     Oyasumi Punpun      manga
# 4            25                                Fullmetal Alchemist      manga
# ...         ...                                                ...        ...
# 24631     62939  Fukushuu Josou Rape!! Namaiki na Kawaii Furyou...  doujinshi
# 24632     46936                                            Houkago   one_shot
# 24633     14203                                 Home Stay x Steady   one_shot
# 24634     97381                                         Oni Shimin   one_shot
# 24635     92740                         Nichijou Sahanji no Musuko   one_shot
#
# ...

# %%
#save datasets

# %%
datapath = '../Data'
save_file(anime_data, 'anime_data.csv', datapath)
# Out:
# Directory ../Data was created.
# Writing file.  "../Data\anime_data.csv"

# %%
save_file(manga_data, 'manga_data.csv', datapath)
# Out:
# Writing file.  "../Data\manga_data.csv"
